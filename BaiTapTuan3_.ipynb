# %% [markdown]
# ##### W3A1 Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau.
# ##### Input Output
# ##### 1234  4231
# ##### 2762  2672

# %%
n = int(input())
s = str(n)
ans = s[::-1]
print(ans)
# Out:
# 29283

# %% [markdown]
# ##### W3A2: Hoán đổi hai số không sd biến tạm thời. Sử dụng phép toán XOR bitwise để hoán đổi giá trị của hai biến.

# %%
a, b = map(int,input().split())
a = a^b
b = b^a
a = a^b
print (a,b)
# Out:
# 5 4

# %% [markdown]
# ##### W3A3: Kiểm tra xem một số có phải là lũy thừa của 2 hay không. Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không. Gợi ý: Đối với lũy thừa của 2, n & (n-1) == 0

# %%
def check(a):
    if ((a&(a-1))==0):
        return True
    else:
        return False

a = int(input())
print(check(a))
# Out:
# False

# %% [markdown]
# ##### W3A4: viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
m, n = map(float,input().split())
ans = int(m/n)
print (ans)
# Out:
# 6129

# %% [markdown]
# ##### W3A5: viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
m, n = map(float,input().split())
tmp = int(m/n)
if (n*tmp<m):
    ans = tmp+1
else:
    ans = tmp
print (ans)
# Out:
# 1221

# %% [markdown]
# ##### W3A6: [Even and Odd] Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".

# %%
x = int(input())
if (x%2==0):
    print ("Even")
else:
    print ("Odd")
# Out:
# Odd

# %% [markdown]
# ##### W3A7: [Check negative numbers] Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a = int(input())
b = int(input())
if (a<0 and b<0):
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# ##### W3A8: [Longer string] Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False".

# %%
a = str(input())
b = str(input())
if (len(a)>len(b)):
    print ("True")
else:
    print ("False")
# Out:
# False

# %% [markdown]
# ##### W3A9: [Triangle] Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không. Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a = int(input())
b = int(input())
c = int(input())
if (a+b>c and b+c>a and c+a>b):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# ##### W3A10: [Largest number] Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
max = a
if (max < b):
    max = b
if (max < c):
    max = c
if (max < d):
    max = d
print (max)
# Out:
# 8

# %% [markdown]
# ##### W3A11: [Phân loại tam giác] Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay "Tam giác thường".

# %%
def check1(a,b,c):
    if (a+b>c and b+c>a and c+a>b):
        return True
    else:
        return False

def check2(a,b,c):
    if (a==b or b==c or b==a):
        if (a==b and b==c):
            print ("Tam giác đều")
        else:
            if (a*a+b*b==c*c or b*b+c*c==a*a or c*c+a*a==b*b):
                print ("Tam giác vuông cân")
            else:
                print ("Tam giác cân")
    else:
        if (a*a+b*b==c*c or b*b+c*c==a*a or c*c+a*a==b*b):
            print ("Tam giác vuông")
        else: 
            print ("Tam giác thường")
    
a, b, c = map(float,input().split())
if (check1(a,b,c)==False):
    print("Không phải tam giác")
else:
    check2(a,b,c)
# Out:
# Tam giác vuông

# %% [markdown]
# ##### W3A12: [Kiểm tra năm nhuận] Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
a = int(input())
if (a%4==0 and a%100!=0):
    print ("Yes")
else:
    print ("No")
# Out:
# No

# %% [markdown]
# ##### W3A13: [Tính tiền điện] Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau:
# - 0-50 kWh: 1500đ/kWh
# - 51-100 kWh: 2000đ/kWh
# - 100 kWh: 3000đ/kWh

# %%
a = int(input())
tmp=a//50
if (tmp==0):
    ans = a*1500
elif (tmp==1):
    ans = (a%50)*2000 + 50*1500
else:
    ans = (a%50 + (tmp-2)*50)*3000 + 50*1500 + 50*2000 
print (ans)
# Out:
# 115000

# %% [markdown]
# ##### W3A14: [Giải phương trình bậc nhất] Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a = float(input())
b = float(input())
if (a==0 and b==0):
    print("Vô Số Nghiệm")
elif (a==0 and b!=0):
    print("Vô nghiệm")
else:
    print(round((b*-1)/a, 2))
# Out:
# -430.87

# %% [markdown]
# ##### W3A15: [Xếp loại học lực] Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc:
# ##### >= 8.0: Giỏi
# ##### >= 6.5: Khá
# ##### >= 5.0: Trung bình
# ##### < 5.0: Yếu

# %%
n = float(input())
if (n>=8):
    print("Giỏi")
elif (n>=6.5 and n<8):
    print("Khá")
elif (n>=5 and n<6.5):
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Giỏi

# %% [markdown]
# ##### W3A16: [Rounding] Nhập vào một số thực: in ra kết quả làm tròn lên ,tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm sẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
n = float(input())
tmp = int(n/1)
if (tmp>=0):
    stx = int(tmp)
    if (n-tmp==0):
        stl = stx
        sngn = stx
    else:
        stl = stx + 1
        if ((n-tmp)>=0.5):
            sngn = stl
        else:
            sngn = stx
else:
    stl = int(tmp)
    if (n-tmp==0):
        stx = stl
        sngn = stl
    else:
        stx = stl - 1
        if ((tmp-n)>=0.5):
            sngn = stx
        else:
            sngn = stl
print (stl, stx, sngn)
# Out:
# 8
# 9 8 8

# %% [markdown]
# ##### W3A17: Cấp số nhân Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng thứ tự a, b, c, d hay không? Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs d.

# %%
def check(a,b,c,d):
    if (b%a==0 and c%b==0 and d%c==0):
        return "YES"
    else:
        return "NO"
a, b, c, d = map(float,input().split())
print(check(a,b,c,d))
# Out:
# NO
